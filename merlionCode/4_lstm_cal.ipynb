# %%
import numpy as np
from sklearn.metrics import f1_score, accuracy_score
from sklearn.metrics import confusion_matrix

def calculate_metrics(conf_matrix):
    # Extract True Positives, False Positives, True Negatives, and False Negatives
    tn, fp, fn, tp = conf_matrix.ravel()

    # Accuracy
    accuracy = accuracy_score([1, 0], [tp, tn])

    # Balanced Accuracy (bAcc)
    sensitivity = tp / (tp + fn)  # True Positive Rate
    specificity = tn / (tn + fp)  # True Negative Rate
    bacc = (sensitivity + specificity) / 2

    # F1 Score
    f1 = f1_score([1, 0], [tp, tn])

    # Equal Error Rate (EER) - the point where False Positive Rate equals False Negative Rate
    eer = (fp / (fp + tn) + fn / (fn + tp)) / 2

    return accuracy, bacc, f1, eer

# Example confusion matrix for binary classification (TP, TN, FP, FN)
conf_matrix = np.array([[6010, 0],  # TN, FP
                        [1440, 2]])  # FN, TP

accuracy, bacc, f1, eer = calculate_metrics(conf_matrix)
print(f"Accuracy: {accuracy}")
print(f"Balanced Accuracy: {bacc}")
print(f"F1 Score: {f1}")
print(f"EER: {eer}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 29
#      25 # Example confusion matrix for binary classification (TP, TN, FP, FN)
#      26 conf_matrix = np.array([[6010, 0],  # TN, FP
#      27                         [1440, 2]])  # FN, TP
# ---> 29 accuracy, bacc, f1, eer = calculate_metrics(conf_matrix)
#      30 print(f"Accuracy: {accuracy}")
#      31 print(f"Balanced Accuracy: {bacc}")
#
# Cell In[1], line 18, in calculate_metrics(conf_matrix)
#      15 bacc = (sensitivity + specificity) / 2
#      17 # F1 Score
# ---> 18 f1 = f1_score([1, 0], [tp, tn])
#      20 # Equal Error Rate (EER) - the point where False Positive Rate equals False Negative Rate
#      21 eer = (fp / (fp + tn) + fn / (fn + tp)) / 2
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/miniconda3/envs/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1518, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1516         if y_type == "multiclass":
#    1517             average_options.remove("samples")
# -> 1518         raise ValueError(
#    1519             "Target is %s but average='binary'. Please "
#    1520             "choose another average setting, one of %r." % (y_type, average_options)
#    1521         )
#    1522 elif pos_label not in (None, 1):
#    1523     warnings.warn(
#    1524         "Note that pos_label (set to %r) is ignored when "
#    1525         "average != 'binary' (got %r). You may use "
#    (...)
#    1528         UserWarning,
#    1529     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

def calculate_metrics(conf_matrix):
    # Extract True Positives, False Positives, True Negatives, and False Negatives
    tn, fp, fn, tp = conf_matrix.ravel()

    # Accuracy
    accuracy = (tp + tn) / (tp + tn + fp + fn)

    # Balanced Accuracy (bAcc)
    sensitivity = tp / (tp + fn)  # True Positive Rate
    specificity = tn / (tn + fp)  # True Negative Rate
    bacc = (sensitivity + specificity) / 2

    # F1 Score
    
    f1 = 2*tp / (2*tp + fp + fn)

    # Equal Error Rate (EER) - the point where False Positive Rate equals False Negative Rate
    eer = (fp / (fp + tn) + fn / (fn + tp)) / 2

    return accuracy, bacc, f1, eer

# Example confusion matrix for binary classification (TN, FP, FN, TP)
conf_matrix = np.array([[6065, 4],  # TN, FP
                        [1378, 5]])  # FN, TP

accuracy, bacc, f1, eer = calculate_metrics(conf_matrix)
print(f"Accuracy: {accuracy}")
print(f"Balanced Accuracy: {bacc}")
print(f"F1 Score: {f1}")
print(f"EER: {eer}")
# Out:
# Accuracy: 0.8145464304884594
# Balanced Accuracy: 0.5014781209153305
# F1 Score: 0.007183908045977011
# EER: 0.49852187908466944

# %%
import numpy as np

def calculate_metrics_from_confusion_matrix(confusion_matrix):
    """
    Calculate accuracy, balanced accuracy, and F1 score from a confusion matrix
    
    Parameters:
    confusion_matrix: 2x2 numpy array or list of lists
        Format:
        [[TN, FP],
         [FN, TP]]
    
    Returns:
    dict: Dictionary containing all metrics
    """
    # Extract values from confusion matrix
    tn, fp = confusion_matrix[0]
    fn, tp = confusion_matrix[1]
    
    # Calculate accuracy
    accuracy = ((tp + tn) / (tp + tn + fp + fn)) * 100
    
    # Calculate sensitivity (recall) and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    
    # Calculate balanced accuracy
    bac = ((sensitivity + specificity) / 2) * 100
    
    # Calculate precision and F1
    precision = tp / (tp + fp)
    f11 = 2 * (precision * sensitivity) / (precision + sensitivity)
    f1 = f11*100
    
    # Calculate EER
    far = fp / (fp + tn)  # False Acceptance Rate
    frr = fn / (fn + tp)  # False Rejection Rate
    eer = (far + frr) / 2  # Approximation of EER
    
    metrics = {
        'accuracy': accuracy,
        'balanced_accuracy': bac,
        'f1_score': f1,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'precision': precision,
        'eer': eer
    }
    
    return metrics

# Example usage
if __name__ == "__main__":
    # Example confusion matrix
    confusion_matrix = [
        [5851, 171],  # [TN, FP]
        [575,  855]   # [FN, TP]
    ]
    
   
    metrics = calculate_metrics_from_confusion_matrix(confusion_matrix)
    
    # Print results with proper formatting
    for metric, value in metrics.items():
        print(f"{metric}: {value:.3f}")
# Out:
# accuracy: 89.989
# balanced_accuracy: 78.475
# f1_score: 69.625
# sensitivity: 0.598
# specificity: 0.972
# precision: 0.833
# eer: 0.215
